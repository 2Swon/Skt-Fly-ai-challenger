# %% [markdown]
# ##

# %%
print('Hello World')
# Out:
# Hello World

# %%
import requests

# %% [markdown]
# ### 네이버 메인페이지 html 가져오기

# %%
response = requests.get('http://www.naver.com')
print(response.text)

# %% [markdown]
# ### 네이버 이미지링크 이미지로 띄우기

# %%
from PIL import Image
from io import BytesIO

# %%
image_path = 'https://blogimg.goo.ne.jp/user_image/64/2b/68516111dcb57156b3b241538890e9f8.jpg'
img = Image.open(BytesIO(requests.get(image_path).content))
print(img.size)
img

# %%
img = img.resize((256, 360))
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x360>

# %% [markdown]
# ### 패키지 다운로드

# %%
# !pip install openai

# %% [markdown]
# # python의 변수 규칙
#
# 문자, 숫자, 밑줄 등을 포함 할 수 있다.
# 숫자는 제일 처음에 나올 수 없다.

# %%
a = 1
b = 2

# %% [markdown]
# 대소문자를 구별한다.

# %%
friend = 1
Friend = 10

friend, Friend
# Out:
# (1, 10)

# %% [markdown]
# 숫자형

# %%
year = 2023
month = 12
print(year, month)
# Out:
# 2023 12

# %%
type(year)
# Out:
# int

# %%
0b10 #2진수
# Out:
# 2

# %%
0o10 # 8진수
# Out:
# 8

# %%
0x10 # 16진수
# Out:
# 16

# %%
oct(38), hex(38), bin(38)
# Out:
# ('0o46', '0x26', '0b100110')

# %%
type(1), type(3.14)
# Out:
# (int, float)

# %%
# 원의 넓이 구하기
import math
pi = math.pi
r= 2
circle_area = pi * (r ** 2)

print(round(circle_area, 2))
# Out:
# 12.57

# %%
# 문자형 실습
"Hello Python"
# Out:
# 'Hello Python'

# %%
"Welcome to 'Python World'"
# Out:
# "Welcome to 'Python World'"

# %%
long_text = '''
항상 태양을 바라 보아라
그리하면 너는 그림자를 볼 수 없을 것이다.

-헬렌켈러
'''
print(long_text)
# Out:
# 항상 태양을 바라 보아라
# 그리하면 너는 그림자를 볼 수 없을 것이다.
#
# -헬렌켈러

# %%
# 이스케이프 문자

print('\t뉴진스\n')
print('\t다니엘\t해린\t민지')
# Out:
# 	뉴진스
#
# 	다니엘	해린	민지

# %%
'py' 'thon'
# Out:
# 'python'

# %%
'py' + 'thon'
# Out:
# 'python'

# %%
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------

# %%
a = 'Python'
a[0]
# Out:
# 'P'

# %%
# Slice
a = 'Welcome to Python World'

# %%
a[:7]
# Out:
# 'Welcome'

# %%
a[0:18:2]
# Out:
# 'Wloet yhn'
